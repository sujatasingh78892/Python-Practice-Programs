# %% [markdown]
# # Create a list containing the names: "Munna Kumar", "Rahul", "Amit", "Sohan"

# %%
a=["Munna Kumar","Rahul","Amit","Sohan"]
a
# Out:
# ['Munna Kumar', 'Rahul', 'Amit', 'Sohan']

# %% [markdown]
# # Print the first element of the list containing "Munna Kumar" and other names.

# %%
a[0]
# Out:
# 'Munna Kumar'

# %% [markdown]
# # Print the last element of the list.

# %%
a[3]
# Out:
# 'Sohan'

# %% [markdown]
# # Find the length of a list containing "Munna Kumar" and 5 other names.

# %%
b=["Munna Kumar","Rahul","Amit","Sohan","Kartik"]
len(b)
# Out:
# 5

# %% [markdown]
# # Check whether "Munna Kumar" exists in the list.

# %%
if "Munna Kumar" in b:
    print("Exist")
else:
    print("Not Exist")
# Out:
# Exist

# %% [markdown]
# # Add "Rohit" to the end of the list.

# %%
b=["Munna Kumar","Rahul","Amit","Sohan","Kartik"]
b.append("Rohit")
b
# Out:
# ['Munna Kumar', 'Rahul', 'Amit', 'Sohan', 'Kartik', 'Rohit']

# %% [markdown]
# # Insert "Munna Kumar" at the beginning of an empty list.

# %%
c=[]
c.insert(0,"Munna Kumar")
c
# Out:
# ['Munna Kumar']

# %% [markdown]
# # Remove "Munna Kumar" from a list.

# %%
b=["Munna Kumar","Rahul","Amit","Sohan","Kartik"]
b.remove("Munna Kumar")
b
# Out:
# ['Rahul', 'Amit', 'Sohan', 'Kartik']

# %% [markdown]
# # Remove the last element from a list using a list method.

# %%
b=["Munna Kumar","Rahul","Amit","Sohan","Kartik"]
b.pop()
b
# Out:
# ['Munna Kumar', 'Rahul', 'Amit', 'Sohan']

# %% [markdown]
# # Find the index of "Munna Kumar" in a list.

# %%
b=["Munna Kumar","Rahul","Amit","Sohan","Kartik"]
b.index("Munna Kumar")
# Out:
# 0

# %% [markdown]
# # Count how many times "Munna Kumar" appears in a list.

# %%
b=["Munna Kumar","Rahul","Munna Kumar","Amit","Sohan","Kartik"]
b.count("Munna Kumar")
# Out:
# 2

# %% [markdown]
# # Sort a list of names that includes "Munna Kumar".

# %%
b=["Munna Kumar","Rahul","Munna Kumar","Amit","Sohan","Kartik"]
b.sort()
b
# Out:
# ['Amit', 'Kartik', 'Munna Kumar', 'Munna Kumar', 'Rahul', 'Sohan']

# %% [markdown]
# # Reverse a list containing "Munna Kumar" and other names.

# %%
b=["Munna Kumar","Rahul","Munna Kumar","Amit","Sohan","Kartik"]
b.reverse()
b
# Out:
# ['Kartik', 'Sohan', 'Amit', 'Munna Kumar', 'Rahul', 'Munna Kumar']

# %% [markdown]
# # Create a copy of a list and print both lists.

# %%
x=[1,2,3]
y=x
print("List of x:",x)
print("List of y:",y)
# Out:
# List of x: [1, 2, 3]
# List of y: [1, 2, 3]

# %% [markdown]
# # Combine two lists where one list contains "Munna Kumar".

# %%
b=["Munna Kumar","Rahul","Amit","Sohan","Kartik"]
c=[1,2,3,4,5]
b+c
# Out:
# ['Munna Kumar', 'Rahul', 'Amit', 'Sohan', 'Kartik', 1, 2, 3, 4, 5]

# %% [markdown]
# # Extract the first three elements from a list containing "Munna Kumar" and other names.

# %%
b=["Munna Kumar","Rahul","Amit","Sohan","Kartik"]
b[0:3]
# Out:
# ['Munna Kumar', 'Rahul', 'Amit']

# %% [markdown]
# # Replace "Munna Kumar" with "Munna Singh" in a list.

# %%
b=["Munna Kumar","Rahul","Amit","Sohan","Kartik"]
b[0]="Munna Singh"
b
# Out:
# ['Munna Singh', 'Rahul', 'Amit', 'Sohan', 'Kartik']

# %% [markdown]
# # Find the smallest and largest number in a list of marks belonging to "Munna Kumar"

# %%
b=[10,45,67,23,12,90]
smallest=min(b)
largest=max(b)
print("Smallest number:",smallest)
print("Largest number:",largest)
# Out:
# Smallest number: 10
# Largest number: 90

# %% [markdown]
# # Create a nested list where the first sublist contains details of "Munna Kumar" (name, age, city)

# %%
a=[["Munna Kumar",25,"Mohali"],["Rohit",28,"Ludhiana"]]
a
# Out:
# [['Munna Kumar', 25, 'Mohali'], ['Rohit', 28, 'Ludhiana']]

# %% [markdown]
# # Iterate through a list and print each name, including "Munna Kumar".

# %%
b=["Munna Kumar","Rahul","Amit","Sohan","Kartik"]
for i in b:
    print(i)
# Out:
# Munna Kumar
# Rahul
# Amit
# Sohan
# Kartik
