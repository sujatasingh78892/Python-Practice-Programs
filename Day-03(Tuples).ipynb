# %% [markdown]
# # Create a tuple containing: Munna, 24, CSE, 2024, 8.98, AI Engineer, Data Science, Cricketer.

# %%
a=("Munna",24,"CSE",2024,8.98,"AI Engineer","Data Science","cricketer")

# %% [markdown]
# # Print the entire tuple.

# %%
a
# Out:
# ('Munna', 24, 'CSE', 2024, 8.98, 'AI Engineer', 'Data Science', 'cricketer')

# %% [markdown]
# # Print only the name from the tuple using indexing.

# %%
a[0]
# Out:
# 'Munna'

# %% [markdown]
# # Print only the age from the tuple

# %%
a[1]
# Out:
# 24

# %% [markdown]
# # Print only the branch (CSE) from the tuple.

# %%
a[2]
# Out:
# 'CSE'

# %% [markdown]
# # Print only the CGPA from the tuple.

# %%
a[4]
# Out:
# 8.98

# %% [markdown]
# # Print the last element of the tuple using negative indexing

# %%
a[-1]
# Out:
# 'cricketer'

# %% [markdown]
# # Print the second-last element using negative indexing.

# %%
a[-2]
# Out:
# 'AI Engineer'

# %% [markdown]
# # Print the first four elements using slicing.

# %%
a[0:4]
# Out:
# ('Munna', 24, 'CSE', 2024)

# %% [markdown]
# # Print the last three elements using slicing.

# %%
a[-3:]
# Out:
# (8.98, 'AI Engineer', 'Data Science')

# %% [markdown]
# # Find the total number of elements in the tuple.

# %%
len(a)
# Out:
# 7

# %% [markdown]
# # Check whether "Munna" exists in the tuple.

# %%
if "Munna" in a:
    print("Exist")
else:
    print("Not exist")
# Out:
# Exist

# %% [markdown]
# # Check whether "Python Developer" exists in the tuple

# %%
if "Python Developer" in a:
    print("Exist")
else:
    print("Not exist")
# Out:
# Not exist

# %% [markdown]
# # Use a for loop to print all elements of the tuple

# %%
for i in a:
    print(i)
# Out:
# Munna
# 24
# CSE
# 2024
# 8.98
# AI Engineer
# Data Science

# %% [markdown]
# # Use a while loop to print all elements of the tuple

# %%
i=0
while(i<len(a)):
    print(a[i])
    i+=1
# Out:
# Munna
# 24
# CSE
# 2024
# 8.98
# AI Engineer
# Data Science

# %% [markdown]
# # Unpack the tuple into variables: name, age, branch, year, cgpa, profession, specialization, hobby.

# %%
name, age, branch, year, cgpa, profession, specialization, hobby=a
a
# Out:
# ('Munna', 24, 'CSE', 2024, 8.98, 'AI Engineer', 'Data Science', 'cricketer')

# %% [markdown]
# # Print only name, profession, and hobby after unpacking.

# %%
print(name)
print(age)
print(hobby)
# Out:
# Munna
# 24
# cricketer

# %% [markdown]
# # Create a new tuple by adding "Punjab" to the existing tuple.

# %%
a=("Munna",24,"CSE",2024,8.98,"AI Engineer","Data Science","cricketer")
b=("Punjab",)
a+b
# Out:
# ('Munna',
#  24,
#  'CSE',
#  2024,
#  8.98,
#  'AI Engineer',
#  'Data Science',
#  'cricketer',
#  'Punjab')

# %% [markdown]
# # Count how many times "CSE" appears in the tuple

# %%
a.count("CSE")
# Out:
# 1

# %% [markdown]
# # Find the index position of "AI Engineer" in the tuple.

# %%
a.index("AI Engineer")
# Out:
# 5
