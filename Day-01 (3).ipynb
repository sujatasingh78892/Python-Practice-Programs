# %% [markdown]
# # Given a string "Programming", print the first 5 characters using slicing.

# %%
a="sujatasingh"
a[0:5]
# Out:
# 'sujat'

# %% [markdown]
# # Given a string "Programming", print the last 4 characters using slicing.

# %%
a="sujatasingh"
a[-5:-1]
# Out:
# 'sing'

# %% [markdown]
# # Extract the substring "gram" from "Programming" using slicing.

# %%
a="Programming"
a[3:7]
# Out:
# 'gram'

# %% [markdown]
# # Reverse the string "Python" using slicing.

# %%
a="python"
a[::-1]
# Out:
# 'nohtyp'

# %% [markdown]
# # Print every second character of the string "Developer".

# %%
a="Developer"
a[::2]
# Out:
# 'Dvlpr'

# %% [markdown]
# # Print every third character of the string "JavaScript".

# %%
a="JavaScript"
a[::3]
# Out:
# 'Jart'

# %% [markdown]
# # Remove the first and last character from the string "OpenAI" using slicing.

# %%
a="OpenAI"
a[1:-1]
# Out:
# 'penA'

# %% [markdown]
# # Extract the middle 3 characters from the string "Machine".

# %%
a="Machine"
a[2:5]
# Out:
# 'chi'

# %% [markdown]
# # Print the string "Programming" in reverse order, skipping every alternate character.

# %%
a="Programming"
a[::-2]
# Out:
# 'gimroP'

# %% [markdown]
# # Given a string "DataScience", extract "Science" using slicing.

# %%
a="DataScience"
a[4::]
# Out:
# 'Science'

# %% [markdown]
# # Given a string "ArtificialIntelligence", print only the first half of the string.

# %%
a="Artificiallntelligence"
a[0:len(a)//2]
# Out:
# 'Artificiall'

# %% [markdown]
# # Given a string "ArtificialIntelligence", print only the second half of the string.

# %%
a="ArtificiallIntelligence"
a[0:len(a)//4]
# Out:
# 'Artif'

# %% [markdown]
# # Extract the last 5 characters from "ComputerScience".

# %%
a="ComputerScience"
a[-5:]
# Out:
# 'ience'

# %% [markdown]
# # Print all characters except the last 3 from "ComputerScience".

# %%
a="ComputerScience"
a[0:-3]
# Out:
# 'ComputerScie'

# %% [markdown]
# # Given a string "abcdefghij", print characters from index 2 to index 7.

# %%
a="abcdefghij"
a[2:7]
# Out:
# 'cdefg'

# %% [markdown]
# # Given a string "abcdefghij", print characters from index 1 to the end with a step of 2.

# %%
a="abcdefghij"
a[1::2]
# Out:
# 'bdfhj'

# %% [markdown]
# # Reverse only the first 5 characters of the string "Programming".

# %%
a="Programming"
a[-7::-1]
# Out:
# 'rgorP'

# %% [markdown]
# # Extract all characters at even indices from "PythonDeveloper".

# %%
a="PythonDeveloper"
a[1::2]
# Out:
# 'yhneeoe'

# %% [markdown]
# # Extract all characters at odd indices from "PythonDeveloper".

# %%
a="PythonDeveloper"
a[0::2]
# Out:
# 'PtoDvlpr'

# %% [markdown]
# # Given a string "InterviewPreparation", print every second character in reverse order.

# %%
a="InterviewPreparation"
a[::-2]
# Out:
# 'niaaePeven'

# %% [markdown]
# # Check whether a string is a palindrome using slicing.

# %%
a="madam"
rev=a[::-1]
if a==rev:
    print("palindrome string")
else:
    print("Not palindrome")
# Out:
# palindrome string

# %% [markdown]
# # Rotate a string "abcdef" by moving the first 2 characters to the end using slicing.

# %%
a="abcdef"
b=a[0:2]
c=a[2:]
c+b
# Out:
# 'cdefab'

# %% [markdown]
# # Swap the first and second halves of a string using slicing.

# %%
a = "ArtificialIntelligence"
b = a[0:len(a)//2]    
c = a[len(a)//2:]       
c + b
# Out:
# 'ntelligenceArtificialI'

# %% [markdown]
# # Remove all characters at even positions using slicing.

# %%
a="Sujata"
a[::2]
# Out:
# 'Sjt'

# %% [markdown]
# # Extract the domain name from the string "user@gmail.com" using slicing.

# %%
a="user@gmail.com"
a[4::]
# Out:
# '@gmail.com'

# %% [markdown]
# # Extract the file extension from "document.pdf" using slicing.

# %%
a="document.pdf"
a[-4:]
# Out:
# '.pdf'

# %% [markdown]
# # |Given "2025-06-08", extract the year, month, and day using slicing.

# %%
a="2025-06-08"
print("Year:",a[0:4])
print("Month:",a[5:7])
print("Day:",a[8:10])
# Out:
# Year: 2025
# Month: 06
# Day: 08

# %% [markdown]
# # Convert "abcdef" into "fedcba" using slicing only.

# %%
a="abcdef"
a[::-1]
# Out:
# 'fedcba'

# %% [markdown]
# # Print the string "HelloWorld" as "WorldHello" using slicing.

# %%
a="HelloWorld"
b=a[0:5]
c=a[5:11]
c+b
# Out:
# 'WorldHello'

# %% [markdown]
# # Given a string "CompetitiveProgramming", extract "Programming" and reverse it using slicing.

# %%
a="CompetitiveProgramming"
b=a[11::]
c=b[::-1]
c
# Out:
# 'gnimmargorP'

# %% [markdown]
# # Count how many times "a" appears in "banana" using count().

# %%
a="banana"
a.count("a")
# Out:
# 3

# %% [markdown]
# # Find the first occurrence of "gram" in "Programming" using find().

# %%
a="Programming"
a.find("gram")
# Out:
# 3

# %% [markdown]
# # Find the last occurrence of "a" in "banana" using rfind().

# %%
a="banana"
a.rfind("a")
# Out:
# 5

# %% [markdown]
# # Replace all occurrences of "Python" with "Java" in a sentence using replace().

# %%
a="python"
a.replace("python","Java")
# Out:
# 'Java'

# %% [markdown]
# # Check whether "Python Programming" starts with "Python" using startswith().

# %%
a="PythonProgramming"
a.startswith("Python")
# Out:
# True

# %% [markdown]
# # Convert "hello world" to title case using title().

# %%
a="hello world"
a.title()
# Out:
# 'Hello World'

# %% [markdown]
# # Convert "HELLO WORLD" to lowercase using lower().

# %%
a="HELLO WORLD"
a.lower()
# Out:
# 'hello world'

# %% [markdown]
# # Convert "hello world" to uppercase using upper().

# %%
a="HELLO WORLD"
a.upper()
# Out:
# 'HELLO WORLD'

# %% [markdown]
# # Swap the case of "PyThOn" using swapcase().

# %%
a="PyThOn"
a.swapcase()
# Out:
# 'pYtHoN'

# %% [markdown]
# # Remove leading and trailing spaces from a string using strip().

# %%
a=" Hello World  "
a.strip()
# Out:
# 'Hello World'

# %% [markdown]
# # Remove only leading spaces using lstrip().

# %%
a=" Hello World  "
a.lstrip()
# Out:
# 'Hello World  '

# %% [markdown]
# # Remove only trailing spaces using rstrip().

# %%
a=" Hello World  "
a.rstrip()
# Out:
# ' Hello World'

# %% [markdown]
# # Split "apple,banana,mango" into a list using split().

# %%
a="apple,banana,mango"
a.split()
# Out:
# ['apple,banana,mango']

# %% [markdown]
# # Join ["Python", "Java", "C++"] into a string using join().

# %%
a="Python","Java","C++"
join_string=",".join(a)
join_string
# Out:
# 'Python,Java,C++'

# %% [markdown]
# # Partition "user@gmail.com" using partition().

# %%
a="user@gmail.com"
a.partition("@")
# Out:
# ('user', '@', 'gmail.com')

# %% [markdown]
# # Partition "folder/subfolder/file.txt" from the right using rpartition().

# %%
a="folder/subfolder/file.text"
a.rpartition("subfolder")
# Out:
# ('folder/', 'subfolder', '/file.text')

# %% [markdown]
# # Split a multiline string using splitlines().

# %%
a= """My name is sujata singh 
I am from Ludhiana Currenty 
I am persuing BCA(AI&DS) from RIMT University"""
a.splitlines()
# Out:
# ['My name is sujata singh ',
#  'I am from Ludhiana Currenty ',
#  'I am persuing BCA(AI&DS) from RIMT University']

# %% [markdown]
# # Find the index of "World" in "Hello World" using index().

# %%
a="Hello World"
a.index("World")
# Out:
# 6

# %% [markdown]
# # Find the last index of "a" in "banana" using rindex().

# %%
idx="banana"
idx.rindex("a")
# Out:
# 5

# %% [markdown]
# # Check whether "Python" contains only alphabets using isalpha().

# %%
a="Python"
a.isalpha()
# Out:
# True

# %% [markdown]
# # Check whether "12345" contains only digits using isdigit().

# %%
a="12345"
a.isdigit()
# Out:
# True

# %% [markdown]
# # Check whether "Python123" is alphanumeric using isalnum().

# %%
a="Python123"
a.isalnum()
# Out:
# True

# %% [markdown]
# # Check whether a string contains only spaces using isspace().

# %%
a="   "
a.isspace()
# Out:
# True

# %% [markdown]
# # Check whether "python" is lowercase using islower().

# %%
a="python"
a.islower()
# Out:
# True

# %% [markdown]
# # Check whether "PYTHON" is uppercase using isupper().

# %%
a="PYTHON"
a.isupper()
# Out:
# True

# %% [markdown]
# # Check whether "Python Programming" is title-cased using istitle().

# %%
a="Python Programming"
a.istitle()
# Out:
# True

# %% [markdown]
# # Check whether "variable_name" is a valid identifier using isidentifier().

# %%
a="variable_name"
a.isidentifier()
# Out:
# True

# %% [markdown]
# # Check whether "123.45" is numeric using isnumeric().

# %%
a="123.45"
a.isnumeric()
# Out:
# False

# %% [markdown]
# # Check whether "½" is numeric using isnumeric().

# %%
a="1/2"
a.isnumeric()
# Out:
# False

# %% [markdown]
# # Center the string "Python" in a width of 20 using center().

# %%
a="Python"
a.center(20)
# Out:
# '       Python       '

# %% [markdown]
# # Left-align "Python" in a width of 15 using ljust().

# %%
a="Python"
a.ljust(15)
# Out:
# 'Python         '

# %% [markdown]
# # Right-align "Python" in a width of 15 using rjust().

# %%
a="Python"
a.rjust(15)
# Out:
# '         Python'

# %% [markdown]
# # Pad "42" with zeros to make it 5 digits using zfill().

# %%
a="42"
a.zfill(5)
# Out:
# '00042'

# %% [markdown]
# # Format "python programming" so only the first character is uppercase using capitalize().

# %%
a="python programming"
a.capitalize()
# Out:
# 'Python programming'

# %% [markdown]
# # Extract the username from "user@gmail.com" using string methods.

# %%
a="user@gmail.com"
a.partition("@")[0]
# Out:
# 'user'

# %% [markdown]
# # Extract the domain name from "user@gmail.com" using string methods.

# %%
a="user@gmail.com"
a.partition("@")[2]
# Out:
# 'gmail.com'

# %% [markdown]
# # Extract the file extension from "report.pdf" using string methods.

# %%
a="report.pdf"
a.partition(".")[2]
# Out:
# 'pdf'

# %% [markdown]
# # Count the number of words in a sentence using split().

# %%
a="Python Programming"
splt=a.split()
cnt=len(splt)
cnt
# Out:
# 2

# %% [markdown]
# # Find the longest word in a sentence using split().

# %%
a="Python Programming"
max(a.split(),key=len)
# Out:
# 'Programming'

# %% [markdown]
# # Find the shortest word in a sentence using split().

# %%
a="Python Programming"
min(a.split(),key=len)
# Out:
# 'Python'

# %% [markdown]
# # Reverse the order of words in a sentence using split() and join().

# %%
a="Python is a high level language."
b=a[::-1]
print("Using split:",b.split())
c=" ".join(b)
print("Using join:",c)
# Out:
# Using split: ['.egaugnal', 'level', 'hgih', 'a', 'si', 'nohtyP']
# Using join: . e g a u g n a l   l e v e l   h g i h   a   s i   n o h t y P

# %% [markdown]
# # Replace all spaces in a sentence with hyphens using replace().

# %%
a="Python is a high level language"
a.replace(" ","_")
# Out:
# 'Python_is_a_high_level_language'

# %% [markdown]
# # Convert a sentence into a list of words using split().

# %%
a="My name is sujata singh."
a.split()
# Out:
# ['My', 'name', 'is', 'sujata', 'singh.']

# %% [markdown]
# # Join a list of words into a sentence using join().

# %%
fruits=["Apple,Banana,Mango,Grapes"]
joins=" ".join(fruits)
joins
# Out:
# 'Apple,Banana,Mango,Grapes'

# %% [markdown]
# # Count the number of occurrences of each word in a sentence using split() and count().

# %%
a="Apple Banana Apple Mango Apple Banana."
words=a.split()
print("Apple:",a.count("Apple"))
print("Banana:",a.count("Banana"))
print("Mango:",a.count("Mango"))
# Out:
# Apple: 3
# Banana: 2
# Mango: 1

# %% [markdown]
# # Remove extra spaces between words using split() and join().

# %%
a="Hello   World"
words=a.split()
" ".join(words)
# Out:
# 'Hello World'

# %% [markdown]
# # Check whether an email contains both "@" and "." using string methods

# %%
a="@gmail.com"
if "@"in a and "." in a :
    print("Valid")
else:
    print("Not valid")
# Out:
# Valid

# %% [markdown]
# # Extract the first word and last word from a sentence using split().

# %%
a="Hello Python programming."
word=a.split()
print("First word:",words[0])
print("Last word:",word[2])
# Out:
# First word: Hello
# Last word: programming.

# %% [markdown]
# # Convert "hello_world_python" into "hello world python" using replace()

# %%
a="hello_world_python"
a.replace("_"," ")
# Out:
# 'hello world python'

# %% [markdown]
# # Check whether "document.pdf" ends with ".pdf" using endswith()

# %%
a="document.pdf"
a.endswith(".pdf")
# Out:
# True
